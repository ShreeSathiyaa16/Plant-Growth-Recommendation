# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/plant_growth_data.csv')

# %%
df.head()
# Out:
#   Soil_Type  Sunlight_Hours Water_Frequency Fertilizer_Type  Temperature  \
# 0      loam        5.192294       bi-weekly        chemical    31.719602
# 1     sandy        4.033133          weekly         organic    28.919484
# 2      loam        8.892769       bi-weekly            none    23.179059
# 3      loam        8.241144       bi-weekly            none    18.465886
# 4     sandy        8.374043       bi-weekly         organic    18.128741
#
#     Humidity  Growth_Milestone
# 0  61.591861                 0
# 1  52.422276                 1
# 2  44.660539                 0
# 3  46.433227                 0
# 4  63.625923                 0

# %%
df.tail()
# Out:
#     Soil_Type  Sunlight_Hours Water_Frequency Fertilizer_Type  Temperature  \
# 188     sandy           5.652           daily            none         28.0
# 189      clay           7.528          weekly        chemical         30.5
# 190      loam           4.934       bi-weekly            none         24.5
# 191     sandy           8.273           daily         organic         27.9
# 192      clay           6.732          weekly            none         21.7
#
#      Humidity  Growth_Milestone
# 188      70.2                 0
# 189      60.1                 1
# 190      61.7                 0
# 191      69.5                 1
# 192      56.9                 0

# %% [markdown]
# ***DESCRIBING THE DATA***

# %%
df.describe()
# Out:
#        Sunlight_Hours  Temperature    Humidity  Growth_Milestone
# count      193.000000   193.000000  193.000000        193.000000
# mean         6.826484    25.076087   58.098927          0.497409
# std          1.599509     5.354170   12.631799          0.501294
# min          4.033133    15.200000   30.567682          0.000000
# 25%          5.477000    20.637095   49.300000          0.000000
# 50%          6.833290    25.912336   59.182806          0.000000
# 75%          8.241144    29.757938   69.100000          1.000000
# max          9.913903    34.810103   79.648240          1.000000

# %%
df.sample()
# Out:
#     Soil_Type  Sunlight_Hours Water_Frequency Fertilizer_Type  Temperature  \
# 163      loam           9.043          weekly         organic         26.4
#
#      Humidity  Growth_Milestone
# 163      70.1                 1

# %%
df.sample(10)
# Out:
#     Soil_Type  Sunlight_Hours Water_Frequency Fertilizer_Type  Temperature  \
# 138      clay        7.428000           daily            none    26.900000
# 161     sandy        4.917000           daily        chemical    28.700000
# 148      loam        5.334000           daily         organic    17.600000
# 147      clay        7.856000          weekly            none    26.200000
# 107     sandy        8.318000          weekly            none    20.100000
# 108      clay        6.134000           daily            none    27.400000
# 121      loam        7.456000       bi-weekly            none    24.600000
# 63       clay        9.657458           daily         organic    15.465439
# 27       loam        4.152515           daily        chemical    24.469435
# 171      clay        6.341000          weekly         organic    30.900000
#
#       Humidity  Growth_Milestone
# 138  68.200000                 0
# 161  54.500000                 1
# 148  57.700000                 0
# ...

# %%
df.sample(5)
# Out:
#     Soil_Type  Sunlight_Hours Water_Frequency Fertilizer_Type  Temperature  \
# 129      clay        6.127000           daily            none    25.700000
# 25      sandy        7.136397           daily            none    16.956683
# 50       clay        9.376548          weekly            none    33.829296
# 112      loam        8.442000       bi-weekly            none    19.300000
# 22       clay        7.367663           daily            none    32.109212
#
#       Humidity  Growth_Milestone
# 129  70.900000                 1
# 25   34.067439                 0
# 50   78.108627                 0
# 112  54.100000                 1
# 22   33.638150                 0

# %% [markdown]
# ***BASIC DATA EXPLORATION***

# %% [markdown]
# ***CHECKING THE SHAPE***

# %%
df.shape
# Out:
# (193, 7)

# %% [markdown]
# ***CHECKING THE COLUMNS***

# %%
df.columns
# Out:
# Index(['Soil_Type', 'Sunlight_Hours', 'Water_Frequency', 'Fertilizer_Type',
#        'Temperature', 'Humidity', 'Growth_Milestone'],
#       dtype='object')

# %% [markdown]
# ***CHECKING THE DATATYPES***

# %%
df.dtypes
# Out:
# Soil_Type            object
# Sunlight_Hours      float64
# Water_Frequency      object
# Fertilizer_Type      object
# Temperature         float64
# Humidity            float64
# Growth_Milestone      int64
# dtype: object

# %% [markdown]
# ***LOOKING FOR MISSING VALUES***

# %%
df.isnull()
# Out:
#      Soil_Type  Sunlight_Hours  Water_Frequency  Fertilizer_Type  Temperature  \
# 0        False           False            False            False        False
# 1        False           False            False            False        False
# 2        False           False            False            False        False
# 3        False           False            False            False        False
# 4        False           False            False            False        False
# ..         ...             ...              ...              ...          ...
# 188      False           False            False            False        False
# 189      False           False            False            False        False
# 190      False           False            False            False        False
# 191      False           False            False            False        False
# 192      False           False            False            False        False
#
#      Humidity  Growth_Milestone
# ...

# %%
df.isnull().any()
# Out:
# Soil_Type           False
# Sunlight_Hours      False
# Water_Frequency     False
# Fertilizer_Type     False
# Temperature         False
# Humidity            False
# Growth_Milestone    False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# Soil_Type           0
# Sunlight_Hours      0
# Water_Frequency     0
# Fertilizer_Type     0
# Temperature         0
# Humidity            0
# Growth_Milestone    0
# dtype: int64

# %% [markdown]
# ***PUTTING IT ALL TOGETHER***

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Soil_Type         193 non-null    object
#  1   Sunlight_Hours    193 non-null    float64
#  2   Water_Frequency   193 non-null    object
#  3   Fertilizer_Type   193 non-null    object
#  4   Temperature       193 non-null    float64
#  5   Humidity          193 non-null    float64
#  6   Growth_Milestone  193 non-null    int64
# dtypes: float64(3), int64(1), object(3)
# memory usage: 10.7+ KB

# %% [markdown]
# ***LOOKING FOR DUPLICATES***

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 188    False
# 189    False
# 190    False
# 191    False
# 192    False
# Length: 193, dtype: bool

# %%
df.duplicated().any()
# Out:
# False

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ***STATISTICAL DESCRIPTION***

# %%
df.describe(include="all")
# Out:
#        Soil_Type  Sunlight_Hours Water_Frequency Fertilizer_Type  Temperature  \
# count        193      193.000000             193             193   193.000000
# unique         3             NaN               3               3          NaN
# top         clay             NaN           daily            none          NaN
# freq          67             NaN              74              74          NaN
# mean         NaN        6.826484             NaN             NaN    25.076087
# std          NaN        1.599509             NaN             NaN     5.354170
# min          NaN        4.033133             NaN             NaN    15.200000
# 25%          NaN        5.477000             NaN             NaN    20.637095
# 50%          NaN        6.833290             NaN             NaN    25.912336
# 75%          NaN        8.241144             NaN             NaN    29.757938
# max          NaN        9.913903             NaN             NaN    34.810103
#
# ...

# %% [markdown]
# ***DATA*** ***VISUALIZATIONS***

# %% [markdown]
# ***HISTOGRAM***

# %%
plt.figure(figsize=(10,5))
sns.histplot(df['Soil_Type'])
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.histplot(df['Water_Frequency'])
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.histplot(df['Fertilizer_Type'])
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.histplot(df['Growth_Milestone'])
plt.show()

# %%
plt.figure(figsize=((12,3)))
sns.histplot(df['Soil_Type'], bins=20)
plt.show()

# %%
df.hist(layout=(1,7), figsize=(18,3))
plt.show()

# %% [markdown]
# ***BOX PLOT***

# %%
sns.boxplot(data=df, y='Humidity')
plt.show()

# %%
sns.boxplot(data=df, y='Temperature')
plt.show()

# %%
sns.boxplot(data=df, y='Sunlight_Hours')
plt.show()

# %%
plt.figure(figsize=(10,7))
sns.boxplot(data=df, y='Soil_Type', x='Humidity')
plt.show()

# %%
plt.figure(figsize=(10,7))
sns.boxplot(data=df, y='Temperature', x='Humidity')
plt.show()

# %%
plt.figure(figsize=(10,7))
sns.boxplot(data=df, y='Sunlight_Hours', x='Water_Frequency')
plt.show()

# %%
plt.figure(figsize=(10,7))
sns.boxplot(data=df, y='Soil_Type', x='Sunlight_Hours', hue='Water_Frequency')
plt.show()

# %%
plt.figure(figsize=(10,7))
sns.boxplot(data=df, y='Fertilizer_Type', x='Temperature', hue='Growth_Milestone')
plt.show()

# %% [markdown]
# ***BOXEN PLOT***

# %%
sns.boxenplot(data=df, y='Temperature')
plt.show()

# %%
sns.boxenplot(data=df, y='Humidity')
plt.show()

# %%
sns.boxenplot(data=df, y='Sunlight_Hours')
plt.show()

# %%
plt.figure(figsize=(10,7))
sns.boxenplot(data=df, y='Soil_Type', x='Sunlight_Hours')
plt.show()

# %%
plt.figure(figsize=(10,7))
sns.boxenplot(data=df, y='Water_Frequency', x='Humidity')
plt.show()

# %%
plt.figure(figsize=(10,7))
sns.boxenplot(data=df, y='Fertilizer_Type', x='Temperature')
plt.show()

# %%
plt.figure(figsize=(10,7))
sns.boxenplot(data=df, y='Humidity', x='Water_Frequency', hue='Soil_Type')
plt.show()

# %%
plt.figure(figsize=(10,7))
sns.boxenplot(data=df, y='Sunlight_Hours', x='Growth_Milestone', hue='Fertilizer_Type')
plt.show()

# %% [markdown]
# ***VIOLIN PLOT***

# %%
sns.violinplot(data=df, y='Humidity')
plt.show()

# %%
sns.violinplot(data=df, y='Soil_Type')
plt.show()

# %%
sns.violinplot(data=df, y='Temperature')
plt.show()

# %%
sns.violinplot(data=df, y='Growth_Milestone')
plt.show()

# %%
plt.figure(figsize=(10,7))
sns.violinplot(data=df, y='Soil_Type', x='Temperature')
plt.show()

# %%
plt.figure(figsize=(10,7))
sns.violinplot(data=df, y='Humidity', x='Water_Frequency')
plt.show()

# %%
plt.figure(figsize=(10,7))
sns.violinplot(data=df, y='Fertilizer_Type', x='Growth_Milestone')
plt.show()

# %%
plt.figure(figsize=(10,7))
sns.violinplot(data=df, y='Sunlight_Hours', x='Growth_Milestone', hue='Temperature')
plt.show()

# %%
plt.figure(figsize=(10,7))
sns.violinplot(data=df, y='Temperature', x='Fertilizer_Type', hue='Soil_Type')
plt.show()

# %%
plt.figure(figsize=(10,7))
sns.violinplot(data=df, y='Water_Frequency', x='Humidity', hue='Fertilizer_Type')
plt.show()

# %%
plt.figure(figsize=(10,7))
sns.violinplot(data=df, y='Soil_Type', x='Sunlight_Hours', hue='Water_Frequency',split=True)
plt.show()

# %%
plt.figure(figsize=(10,7))
sns.violinplot(data=df, y='Temperature', x='Fertilizer_Type', hue='Growth_Milestone',split=True)
plt.show()

# %%
plt.figure(figsize=(10,7))
sns.violinplot(data=df, y='Humidity', x='Fertilizer_Type', hue='Growth_Milestone',split=True)
plt.show()

# %% [markdown]
# ***SCATTER PLOT***

# %%
plt.figure(figsize=(5,2))
sns.scatterplot(data=df, y='Soil_Type', x='Sunlight_Hours')
plt.show()

# %%
plt.figure(figsize=(5,2))
sns.scatterplot(data=df, y='Water_Frequency', x='Fertilizer_Type')
plt.show()

# %%
plt.figure(figsize=(5,2))
sns.scatterplot(data=df, y='Temperature', x='Growth_Milestone')
plt.show()

# %%
plt.figure(figsize=(5,2))
sns.scatterplot(data=df, x='Temperature', y='Growth_Milestone')
plt.show()

# %%
plt.figure(figsize=(5,2))
sns.scatterplot(data=df, y='Soil_Type', x='Sunlight_Hours', hue='Water_Frequency')
plt.show()

# %%
plt.figure(figsize=(5,2))
sns.scatterplot(data=df, y='Temperature', x='Fertilizer_Type', hue='Growth_Milestone')
plt.show()

# %%
plt.figure(figsize=(5,2))
sns.scatterplot(data=df, x='Humidity', y='Fertilizer_Type', hue='Growth_Milestone')
plt.show()

# %% [markdown]
# ***MULTIVARIATE PLOT***

# %%
sns.pairplot(df[['Soil_Type','Sunlight_Hours','Water_Frequency','Fertilizer_Type']])
plt.show()

# %%
sns.pairplot(df[['Fertilizer_Type','Temperature','Humidity','Growth_Milestone']])
plt.show()

# %% [markdown]
# ***BAR PLOT***

# %%
sns.barplot(x=df['Fertilizer_Type'].value_counts().index,
            y=df['Fertilizer_Type'].value_counts().values)
plt.show()

# %%
sns.barplot(x=df['Water_Frequency'].value_counts().index,
            y=df['Water_Frequency'].value_counts().values)
plt.show()

# %%
sns.barplot(x=df['Growth_Milestone'].value_counts().index,
            y=df['Growth_Milestone'].value_counts().values)
plt.show()

# %%
sns.barplot(x=df['Temperature'].value_counts().index,
            y=df['Temperature'].value_counts().values)
plt.show()

# %%
sns.barplot(y=df['Sunlight_Hours'].value_counts().index,
            x=df['Sunlight_Hours'].value_counts().values)
plt.show()

# %% [markdown]
# ***CROSS TAB***

# %%
pd.crosstab(index=df['Soil_Type'], columns=df['Fertilizer_Type'])
# Out:
# Fertilizer_Type  chemical  none  organic
# Soil_Type
# clay                   25    24       18
# loam                   17    24       21
# sandy                  23    26       15

# %%
pd.crosstab(index=df['Sunlight_Hours'], columns=df['Water_Frequency'])
# Out:
# Water_Frequency  bi-weekly  daily  weekly
# Sunlight_Hours
# 4.033133                 0      0       1
# 4.041713                 0      1       0
# 4.118000                 1      0       0
# 4.152515                 0      1       0
# 4.188575                 1      0       0
# ...                    ...    ...     ...
# 9.657458                 0      1       0
# 9.774684                 0      0       1
# 9.830692                 0      0       1
# 9.872000                 1      0       0
# 9.913903                 0      1       0
#
# [190 rows x 3 columns]

# %%
pd.crosstab(index=df['Humidity'], columns=df['Growth_Milestone'])
# Out:
# Growth_Milestone  0  1
# Humidity
# 30.567682         0  1
# 30.607724         0  1
# 32.157996         1  0
# 32.272319         0  1
# 32.815164         1  0
# ...              .. ..
# 78.719740         1  0
# 79.300053         1  0
# 79.310537         1  0
# 79.331979         1  0
# 79.648240         1  0
#
# [191 rows x 2 columns]

# %% [markdown]
# ***COUNT PLOT***

# %%
sns.countplot(data=df, x='Soil_Type')
plt.show()

# %%
sns.countplot(data=df, x='Water_Frequency')
plt.show()

# %% [markdown]
# ***EXPLORING CATEGORICAL DATA***

# %%
df['Soil_Type'].value_counts()
# Out:
# Soil_Type
# clay     67
# sandy    64
# loam     62
# Name: count, dtype: int64

# %%
df['Sunlight_Hours'].value_counts()
# Out:
# Sunlight_Hours
# 7.528000    2
# 6.917000    2
# 6.127000    2
# 4.118000    1
# 7.456000    1
#            ..
# 7.112744    1
# 8.218114    1
# 6.181778    1
# 9.830692    1
# 6.732000    1
# Name: count, Length: 190, dtype: int64

# %%
df['Water_Frequency'].value_counts()
# Out:
# Water_Frequency
# daily        74
# bi-weekly    60
# weekly       59
# Name: count, dtype: int64

# %%
df['Fertilizer_Type'].value_counts()
# Out:
# Fertilizer_Type
# none        74
# chemical    65
# organic     54
# Name: count, dtype: int64

# %%
df['Temperature'].value_counts()
# Out:
# Temperature
# 31.700000    2
# 22.000000    2
# 30.000000    2
# 27.900000    2
# 31.719602    1
#             ..
# 20.637095    1
# 17.363297    1
# 28.934743    1
# 27.578857    1
# 21.700000    1
# Name: count, Length: 189, dtype: int64

# %%
df['Growth_Milestone'].value_counts()
# Out:
# Growth_Milestone
# 0    97
# 1    96
# Name: count, dtype: int64

# %% [markdown]
# ***GRID MAP***

# %%
grid = sns.FacetGrid(data=df, col='Growth_Milestone', height=4, aspect=1, sharey=False)
grid.map(sns.countplot, 'Soil_Type', palette=['black', 'brown', 'orange'])
plt.show()

# %%
grid = sns.FacetGrid(data=df, col='Fertilizer_Type', height=4, aspect=1, sharey=False)
grid.map(sns.countplot, 'Soil_Type', palette=['black', 'brown', 'orange'])
plt.show()

# %%
grid = sns.FacetGrid(data=df, col='Water_Frequency', height=4, aspect=1, sharey=False)
grid.map(sns.countplot, 'Growth_Milestone', palette=['black', 'brown', 'orange'])
plt.show()

# %% [markdown]
# ***INTERACTION BETWEEN NUMERICAL AND CATEGORICAL VARIABLES***

# %% [markdown]
# ***HISTOGRAM***

# %%
plt.figure(figsize=(7,5))
sns.histplot(data=df, x='Soil_Type', bins=16, hue='Growth_Milestone')
plt.show()

# %%
plt.figure(figsize=(7,5))
sns.histplot(data=df, x='Fertilizer_Type', bins=16, hue='Water_Frequency')
plt.show()

# %%
plt.figure(figsize=(7,5))
sns.histplot(data=df, x='Sunlight_Hours', bins=16, hue='Growth_Milestone')
plt.show()

# %%
plt.figure(figsize=(7,5))
sns.histplot(data=df, x='Temperature', bins=16, hue='Soil_Type')
plt.show()

# %% [markdown]
# ***STRIP PLOT***

# %%
plt.figure(figsize=(7,5))
sns.stripplot(data=df, x='Soil_Type', y='Sunlight_Hours')
plt.show()

# %%
plt.figure(figsize=(7,5))
sns.stripplot(data=df, y='Fertilizer_Type', x='Humidity')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.stripplot(data=df, x='Water_Frequency', y='Growth_Milestone')
plt.show()

# %%
plt.figure(figsize=(7,5))
sns.stripplot(data=df, x='Soil_Type', y='Humidity', hue='Growth_Milestone')
plt.show()

# %%
plt.figure(figsize=(7,5))
sns.stripplot(data=df, x='Sunlight_Hours', y='Temperature', hue='Water_Frequency')
plt.show()

# %% [markdown]
# ***SWARM PLOT***

# %%
plt.figure(figsize=(7,5))
sns.swarmplot(data=df, x='Soil_Type', y='Temperature')
plt.show()

# %%
plt.figure(figsize=(7,5))
sns.swarmplot(data=df, x='Humidity', y='Water_Frequency')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.swarmplot(data=df, x='Growth_Milestone', y='Water_Frequency')
plt.show()

# %% [markdown]
# # ***END***
